# %% [markdown]
# # Exercise 2.4
# Author: Sebastian Pritz

# %% [markdown]
# ## Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.svm import SVC

from pyMLaux import plot_2d_prediction

# %%
data_dir = "src/"

# %% [markdown]
# ## Normal Data

# %%
# Read in the data
data = pd.read_csv(data_dir+"Dataset1.csv")
data
# Out:
#            x1        x2  y
# 0    0.914806  0.885118  1
# 1    0.937075  0.517111  1
# 2    0.286140  0.851931  0
# 3    0.830448  0.442796  1
# 4    0.641746  0.157880  1
# ..        ...       ... ..
# 195  0.053129  0.490750  0
# 196  0.531874  0.965256  1
# 197  0.112308  0.906942  0
# 198  0.743188  0.551251  1
# 199  0.731315  0.075599  1
#
# [200 rows x 3 columns]

# %%
def apply_grid_search(X, y):
    # Calc split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1337)

    # Apply gridsearch
    param_grid = [
      {'C': [1, 4, 16, 64, 256], 'kernel': ['linear']},
      {'C': [1, 4, 16, 64, 256], 'gamma': [0.01, 0.001, 0.0001], 'kernel': ['rbf']},
     ]

    svc_grid_search = GridSearchCV(SVC(), param_grid, cv=10, scoring='accuracy', n_jobs=-1)
    svc_grid_search.fit(X_train, y_train)
    
    return svc_grid_search.best_score_, svc_grid_search.best_estimator_, pd.DataFrame(svc_grid_search.cv_results_)

# %%
score, parameters, cv_results = apply_grid_search(data.iloc[:,:-1], data.iloc[:,-1])
print(score, parameters)
cv_results
# Out:
# 0.9071428571428571 SVC(C=4, kernel='linear')
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.001901  3.742159e-04         0.000900    3.747968e-04       1
# 1        0.001616  3.188032e-04         0.000953    3.530398e-04       4
# 2        0.001601  3.000077e-04         0.000899    2.998639e-04      16
# 3        0.001300  3.317908e-04         0.000850    2.286469e-04      64
# 4        0.002149  3.197950e-04         0.001000    8.996946e-07     256
# 5        0.001900  4.353668e-04         0.000900    3.000580e-04       1
# 6        0.001450  1.502790e-04         0.000751    2.509163e-04       1
# 7        0.001602  3.738797e-04         0.000951    2.683933e-04       1
# 8        0.001850  2.289581e-04         0.001049    3.495156e-04       4
# 9        0.001751  4.037353e-04         0.001000    3.871477e-04       4
# 10       0.001751  3.358926e-04         0.001050    3.496338e-04       4
# 11       0.001500  3.167358e-04         0.000850    2.293779e-04      16
# 12       0.002050  2.687218e-04         0.001300    2.447288e-04      16
# 13       0.001850  3.907715e-04         0.000950    2.689559e-04      16
# 14       0.001650  3.205580e-04         0.000950    2.693718e-04      64
# 15       0.001750  3.351939e-04         0.000900    3.004184e-04      64
# 16       0.001700  4.580503e-04         0.000899    3.002592e-04      64
# 17       0.001300  2.449135e-04         0.000800    2.452563e-04     256
# 18       0.001250  2.495070e-04         0.000900    1.999664e-04     256
# 19       0.001500  8.756813e-07         0.000800    2.452636e-04     256
#
#    param_kernel param_gamma                                        params  \
# 0        linear         NaN                  {'C': 1, 'kernel': 'linear'}
# 1        linear         NaN                  {'C': 4, 'kernel': 'linear'}
# 2        linear         NaN                 {'C': 16, 'kernel': 'linear'}
# 3        linear         NaN                 {'C': 64, 'kernel': 'linear'}
# 4        linear         NaN                {'C': 256, 'kernel': 'linear'}
# 5           rbf        0.01      {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 6           rbf       0.001     {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 7           rbf      0.0001    {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 8           rbf        0.01      {'C': 4, 'gamma': 0.01, 'kernel': 'rbf'}
# 9           rbf       0.001     {'C': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# 10          rbf      0.0001    {'C': 4, 'gamma': 0.0001, 'kernel': 'rbf'}
# 11          rbf        0.01     {'C': 16, 'gamma': 0.01, 'kernel': 'rbf'}
# 12          rbf       0.001    {'C': 16, 'gamma': 0.001, 'kernel': 'rbf'}
# 13          rbf      0.0001   {'C': 16, 'gamma': 0.0001, 'kernel': 'rbf'}
# 14          rbf        0.01     {'C': 64, 'gamma': 0.01, 'kernel': 'rbf'}
# 15          rbf       0.001    {'C': 64, 'gamma': 0.001, 'kernel': 'rbf'}
# 16          rbf      0.0001   {'C': 64, 'gamma': 0.0001, 'kernel': 'rbf'}
# 17          rbf        0.01    {'C': 256, 'gamma': 0.01, 'kernel': 'rbf'}
# 18          rbf       0.001   {'C': 256, 'gamma': 0.001, 'kernel': 'rbf'}
# 19          rbf      0.0001  {'C': 256, 'gamma': 0.0001, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  ...  split3_test_score  \
# 0            0.928571           0.857143  ...           0.785714
# 1            0.928571           0.857143  ...           0.857143
# 2            0.928571           0.857143  ...           0.857143
# 3            0.928571           0.928571  ...           0.857143
# 4            0.928571           0.928571  ...           0.857143
# 5            0.642857           0.642857  ...           0.571429
# 6            0.642857           0.642857  ...           0.571429
# 7            0.642857           0.642857  ...           0.571429
# 8            0.928571           0.857143  ...           0.642857
# 9            0.642857           0.642857  ...           0.571429
# 10           0.642857           0.642857  ...           0.571429
# 11           0.928571           0.928571  ...           0.785714
# 12           0.642857           0.642857  ...           0.571429
# 13           0.642857           0.642857  ...           0.571429
# 14           0.928571           0.857143  ...           0.857143
# 15           0.928571           0.928571  ...           0.714286
# 16           0.642857           0.642857  ...           0.571429
# 17           0.928571           0.857143  ...           0.857143
# 18           0.928571           0.928571  ...           0.714286
# 19           0.642857           0.642857  ...           0.571429
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.857143           0.928571           0.857143
# 1            0.857143           0.928571           0.857143
# 2            0.857143           0.928571           0.857143
# 3            0.857143           0.928571           0.857143
# 4            0.857143           0.928571           0.857143
# 5            0.571429           0.571429           0.571429
# 6            0.571429           0.571429           0.571429
# 7            0.571429           0.571429           0.571429
# 8            0.857143           0.785714           0.785714
# 9            0.571429           0.571429           0.571429
# 10           0.571429           0.571429           0.571429
# 11           0.857143           0.928571           0.857143
# 12           0.571429           0.571429           0.571429
# 13           0.571429           0.571429           0.571429
# 14           0.857143           0.928571           0.857143
# 15           0.857143           0.928571           0.785714
# 16           0.571429           0.571429           0.571429
# 17           0.857143           0.928571           0.857143
# 18           0.857143           0.928571           0.857143
# 19           0.571429           0.571429           0.571429
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.857143           1.000000           0.857143         0.892857
# 1            0.928571           1.000000           0.857143         0.907143
# 2            0.928571           1.000000           0.857143         0.900000
# 3            0.928571           1.000000           0.857143         0.907143
# 4            0.928571           1.000000           0.857143         0.907143
# 5            0.571429           0.571429           0.571429         0.592857
# 6            0.571429           0.571429           0.571429         0.592857
# 7            0.571429           0.571429           0.571429         0.592857
# 8            0.928571           0.785714           0.785714         0.814286
# 9            0.571429           0.571429           0.571429         0.592857
# 10           0.571429           0.571429           0.571429         0.592857
# 11           0.857143           1.000000           0.928571         0.907143
# 12           0.571429           0.571429           0.571429         0.592857
# 13           0.571429           0.571429           0.571429         0.592857
# 14           0.928571           1.000000           0.857143         0.907143
# 15           0.857143           1.000000           0.857143         0.885714
# 16           0.571429           0.571429           0.571429         0.592857
# 17           0.928571           1.000000           0.857143         0.907143
# 18           0.857143           1.000000           0.928571         0.900000
# 19           0.571429           0.571429           0.571429         0.592857
#
#     std_test_score  rank_test_score
# 0         0.065854                9
# 1         0.055787                1
# 2         0.047380                7
# 3         0.045737                1
# 4         0.045737                1
# 5         0.032733               12
# 6         0.032733               12
# 7         0.032733               12
# 8         0.079539               11
# 9         0.032733               12
# 10        0.032733               12
# 11        0.064286                1
# 12        0.032733               12
# 13        0.032733               12
# 14        0.055787                1
# 15        0.085714               10
# 16        0.032733               12
# 17        0.055787                1
# 18        0.079539                7
# 19        0.032733               12
#
# [20 rows x 21 columns]

# %% [markdown]
# ## Noisy data

# %%
# Create noisy dataset
noisy_data = data.copy(deep=True)
for i in range(10):
    noisy_data[f"x{i+3}"] = np.random.uniform(size=noisy_data.shape[0])

cols = list(noisy_data.columns.values)
cols.pop(cols.index("y"))
noisy_data = noisy_data[cols + ["y"]]
noisy_data
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# 0    0.914806  0.885118  0.654874  0.566485  0.741465  0.274348  0.411234
# 1    0.937075  0.517111  0.878151  0.163102  0.673953  0.697528  0.612304
# 2    0.286140  0.851931  0.014905  0.999931  0.569159  0.332122  0.861005
# 3    0.830448  0.442796  0.231061  0.994449  0.484634  0.210943  0.470065
# 4    0.641746  0.157880  0.778534  0.138109  0.544111  0.614616  0.786482
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.053129  0.490750  0.584001  0.995700  0.620230  0.726955  0.517594
# 196  0.531874  0.965256  0.193740  0.850563  0.921282  0.890952  0.952668
# 197  0.112308  0.906942  0.970892  0.903322  0.899959  0.571127  0.570785
# 198  0.743188  0.551251  0.596862  0.274259  0.460474  0.653878  0.060860
# 199  0.731315  0.075599  0.998649  0.347780  0.622471  0.407524  0.882620
#
#            x8        x9       x10       x11       x12  y
# 0    0.288198  0.815190  0.762923  0.952080  0.893468  1
# 1    0.902049  0.567415  0.274501  0.434412  0.609641  1
# 2    0.868259  0.202417  0.772833  0.826927  0.724725  0
# 3    0.580222  0.183163  0.249513  0.295766  0.168151  1
# 4    0.932671  0.589753  0.073445  0.748046  0.431293  1
# ..        ...       ...       ...       ...       ... ..
# 195  0.363721  0.910276  0.418493  0.340151  0.738222  0
# 196  0.697984  0.768596  0.404544  0.405616  0.936134  1
# 197  0.777716  0.953050  0.448917  0.818507  0.673018  0
# 198  0.435061  0.831358  0.667371  0.579748  0.385065  1
# 199  0.335508  0.331454  0.699802  0.670488  0.727523  1
#
# [200 rows x 13 columns]

# %%
score, parameters, cv_results = apply_grid_search(noisy_data.iloc[:,:-1], noisy_data.iloc[:,-1])
print(score, parameters)
cv_results
# Out:
# 0.8928571428571429 SVC(C=256, gamma=0.01)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.001949      0.000417         0.001000        0.000001       1
# 1        0.001450      0.000271         0.000893        0.000437       4
# 2        0.001651      0.000232         0.000950        0.000269      16
# 3        0.003701      0.001764         0.001050        0.000350      64
# 4        0.005100      0.001337         0.001051        0.000271     256
# 5        0.002051      0.000269         0.001299        0.000245       1
# 6        0.001850      0.000391         0.001150        0.000320       1
# 7        0.001850      0.000391         0.001050        0.000472       1
# 8        0.001800      0.000458         0.001000        0.000224       4
# 9        0.001800      0.000400         0.000850        0.000320       4
# 10       0.001650      0.000229         0.000951        0.000350       4
# 11       0.002201      0.000244         0.001251        0.000250      16
# 12       0.002201      0.000331         0.001301        0.000459      16
# 13       0.002102      0.000374         0.001251        0.000404      16
# 14       0.001802      0.000333         0.001100        0.000375      64
# 15       0.002000      0.000500         0.001101        0.000200      64
# 16       0.001702      0.000333         0.000851        0.000320      64
# 17       0.001550      0.000152         0.000850        0.000230     256
# 18       0.001650      0.000320         0.000900        0.000200     256
# 19       0.001700      0.000245         0.000850        0.000229     256
#
#    param_kernel param_gamma                                        params  \
# 0        linear         NaN                  {'C': 1, 'kernel': 'linear'}
# 1        linear         NaN                  {'C': 4, 'kernel': 'linear'}
# 2        linear         NaN                 {'C': 16, 'kernel': 'linear'}
# 3        linear         NaN                 {'C': 64, 'kernel': 'linear'}
# 4        linear         NaN                {'C': 256, 'kernel': 'linear'}
# 5           rbf        0.01      {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 6           rbf       0.001     {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 7           rbf      0.0001    {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 8           rbf        0.01      {'C': 4, 'gamma': 0.01, 'kernel': 'rbf'}
# 9           rbf       0.001     {'C': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# 10          rbf      0.0001    {'C': 4, 'gamma': 0.0001, 'kernel': 'rbf'}
# 11          rbf        0.01     {'C': 16, 'gamma': 0.01, 'kernel': 'rbf'}
# 12          rbf       0.001    {'C': 16, 'gamma': 0.001, 'kernel': 'rbf'}
# 13          rbf      0.0001   {'C': 16, 'gamma': 0.0001, 'kernel': 'rbf'}
# 14          rbf        0.01     {'C': 64, 'gamma': 0.01, 'kernel': 'rbf'}
# 15          rbf       0.001    {'C': 64, 'gamma': 0.001, 'kernel': 'rbf'}
# 16          rbf      0.0001   {'C': 64, 'gamma': 0.0001, 'kernel': 'rbf'}
# 17          rbf        0.01    {'C': 256, 'gamma': 0.01, 'kernel': 'rbf'}
# 18          rbf       0.001   {'C': 256, 'gamma': 0.001, 'kernel': 'rbf'}
# 19          rbf      0.0001  {'C': 256, 'gamma': 0.0001, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  ...  split3_test_score  \
# 0            0.928571           0.857143  ...           0.714286
# 1            0.928571           0.857143  ...           0.785714
# 2            0.928571           0.928571  ...           0.785714
# 3            0.928571           0.857143  ...           0.785714
# 4            0.928571           0.928571  ...           0.785714
# 5            0.642857           0.642857  ...           0.571429
# 6            0.642857           0.642857  ...           0.571429
# 7            0.642857           0.642857  ...           0.571429
# 8            0.928571           0.857143  ...           0.571429
# 9            0.642857           0.642857  ...           0.571429
# 10           0.642857           0.642857  ...           0.571429
# 11           0.857143           0.928571  ...           0.785714
# 12           0.642857           0.642857  ...           0.571429
# 13           0.642857           0.642857  ...           0.571429
# 14           0.857143           0.857143  ...           0.714286
# 15           0.857143           0.785714  ...           0.785714
# 16           0.642857           0.642857  ...           0.571429
# 17           0.928571           0.857143  ...           0.785714
# 18           0.857143           0.857143  ...           0.714286
# 19           0.642857           0.642857  ...           0.571429
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.785714           0.857143           0.857143
# 1            0.785714           0.928571           0.928571
# 2            0.714286           0.928571           0.928571
# 3            0.642857           0.928571           0.928571
# 4            0.714286           0.928571           0.928571
# 5            0.571429           0.571429           0.571429
# 6            0.571429           0.571429           0.571429
# 7            0.571429           0.571429           0.571429
# 8            0.857143           0.785714           0.714286
# 9            0.571429           0.571429           0.571429
# 10           0.571429           0.571429           0.571429
# 11           0.785714           0.857143           0.857143
# 12           0.571429           0.571429           0.571429
# 13           0.571429           0.571429           0.571429
# 14           0.785714           0.857143           0.857143
# 15           0.785714           0.928571           0.785714
# 16           0.571429           0.571429           0.571429
# 17           0.857143           0.928571           0.928571
# 18           0.857143           0.857143           0.857143
# 19           0.571429           0.571429           0.571429
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.928571           1.000000           0.857143         0.871429
# 1            0.928571           1.000000           0.857143         0.885714
# 2            0.857143           1.000000           0.857143         0.864286
# 3            0.857143           1.000000           0.857143         0.857143
# 4            0.857143           1.000000           0.857143         0.871429
# 5            0.571429           0.571429           0.571429         0.592857
# 6            0.571429           0.571429           0.571429         0.592857
# 7            0.571429           0.571429           0.571429         0.592857
# 8            0.857143           0.785714           0.714286         0.778571
# 9            0.571429           0.571429           0.571429         0.592857
# 10           0.571429           0.571429           0.571429         0.592857
# 11           0.928571           1.000000           0.857143         0.878571
# 12           0.571429           0.571429           0.571429         0.592857
# 13           0.571429           0.571429           0.571429         0.592857
# 14           0.928571           1.000000           0.857143         0.864286
# 15           0.857143           1.000000           0.857143         0.857143
# 16           0.571429           0.571429           0.571429         0.592857
# 17           0.928571           1.000000           0.857143         0.892857
# 18           0.928571           1.000000           0.857143         0.871429
# 19           0.571429           0.571429           0.571429         0.592857
#
#     std_test_score  rank_test_score
# 0         0.076931                5
# 1         0.065465                2
# 2         0.092857                7
# 3         0.095831                9
# 4         0.083299                4
# 5         0.032733               12
# 6         0.032733               12
# 7         0.032733               12
# 8         0.098198               11
# 9         0.032733               12
# 10        0.032733               12
# 11        0.064286                3
# 12        0.032733               12
# 13        0.032733               12
# 14        0.074574                7
# 15        0.071429                9
# 16        0.032733               12
# 17        0.057588                1
# 18        0.069985                5
# 19        0.032733               12
#
# [20 rows x 21 columns]

# %% [markdown]
# ## Observations

# %% [markdown]
# As can be seen in the tables above, for the normal data several methods were applicable and shared the highest accuracy of about 90.7%. This is not the case for noisy data, as all parameter configurations are at least 1.5% behind, down to 89.2% and rank 1 isn't shared.
